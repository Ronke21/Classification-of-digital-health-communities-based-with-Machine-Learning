# %% [markdown]
# # **Machine Learning Final Project**
#
#
# ### Ron Keinan 203735857

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# Notebook # 4 - In this notebook I will classify df with 2 imbalanced classes in the same way of notebook #1, but first will balance the dataset with Random undersampling. now the results should be better than #2.

# %% [markdown]
# # **Data preperation**

# %% [markdown]
# ##### **Downloading the data set**

# %%
import os
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import Font, Alignment, Border, Side
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, BaggingClassifier
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_fscore_support
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, VotingClassifier
import imblearn
from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from collections import Counter
from string import punctuation
import numpy as np
import math
import seaborn as sns

import nltk
nltk.download('punkt')

import matplotlib.pyplot as plt
# %matplotlib inline

import time
t1 = time.perf_counter()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data_path = '/content/gdrive/MyDrive/Machine Learning course 5783/Final Project/data/'
full_data = pd.read_excel(data_path+'camoni full comments.xlsx')
full_data['Community'].value_counts()
# Out:
# דיכאון וחרדה                62221
# הפרעות אכילה                36950
# ער"ן - עזרה ראשונה נפשית    35618
# טרשת נפוצה                  21422
# כאב                         15715
# קרוהן וקוליטיס              15179
# סוכרת סוג-2                 14715
# תרופות ורוקחות              13057
# כליות ודיאליזה              10557
# חוט שדרה                     6831
# נשימה                        5433
# קשב וריכוז                   5210
# השמנה                        5202
# מחלות לב                     5124
# אוסטאופורוזיס                4715
# לחץ דם                       3922
# סרטן                         3501
# מפרקים                       3438
# גמילה מעישון                 3391
# זכויות החולה                 2681
# אירוע מוחי                   2475
# שלפוחית רגיזה                2258
# פסוריאזיס                    2181
# סרטן השד                     1765
# מיאלומה נפוצה                1705
# סיוגרן (sjogren)             1359
# מושתלים                       888
# בני משפחה מטפלים              851
# טראומה מטרור ומלחמה           828
# בעיות גדילה                   818
# פיברומיאלגיה                  659
# אטופיק דרמטיטיס               498
# סרטן המעי הגס                 493
# סרטן הריאות                   472
# סוכרת סוג-1                   308
# קדחת ים תיכונית (FMF...       307
# סרטן השחלות                   215
# הידרדניטיס סופורטיבה          197
# סרטן שלפוחית השתן             131
# ניוון מקולרי גילי (A...        48
# נזאל פוליפוזיס                 20
# Name: Community, dtype: int64

# %%
data = full_data[full_data['Community'].isin(['הידרדניטיס סופורטיבה', 'סרטן הריאות'])]

# %%
data['Community'] = data['Community'].replace('סרטן הריאות', 'lung cancer')
data['Community'] = data['Community'].replace('הידרדניטיס סופורטיבה','hydradenitis suppurativa')
# Out:
# <ipython-input-5-7af39f4a9cbc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Community'] = data['Community'].replace('סרטן הריאות', 'lung cancer')
# <ipython-input-5-7af39f4a9cbc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Community'] = data['Community'].replace('הידרדניטיס סופורטיבה','hydradenitis suppurativa')

# %%
data
# Out:
#             Date   Time    Community     Comment author  \
# 117136  20/03/16  12:28  lung cancer             רחלה\n
# 117137  21/03/16  10:30  lung cancer  ד"ר מיה גוטפריד\n
# 117138  27/03/16  10:44  lung cancer         אפרת_זיו\n
# 117139  24/04/16   0:21  lung cancer           ד"ר טל\n
# 117140  20/03/16  12:47  lung cancer         אנונימית\n
# ...          ...    ...          ...                ...
# 287320  31/10/21   8:09  lung cancer     ד"ר אמיר און\n
# 287321  01/11/21   9:50  lung cancer          רון1504\n
# 287322  02/11/21  10:02  lung cancer     ד"ר אמיר און\n
# 287811  02/11/21  12:54  lung cancer       לירן.לוי\n\n
# 287812  09/11/21   8:00  lung cancer     ד"ר אמיר און\n
#
#                                                   Comment Post/Comment
# 117136  \nבכימו והקרנות או שיש אפשרויות נוספות? תודה \...         post
# 117137           תלוי בשלב המחלה\nישנן אופציות נוספות\n\n      comment
# 117138                                         כמו מה\n\n      comment
# 117139          היי רחלה\nקיימים טיפולים ביולוגים. \n\n\n      comment
# 117140             \nציספלטין+וינבלסטין למה לצפות? \n\n\n         post
# ...                                                   ...          ...
# 287320  לפי התיאור הזה יש רק ממצא אחד – קשרית LUL =LEF...      comment
# 287321  תודה!\nהרדיולוג הרי ראה את ה-CT וזה מה שהוא כת...      comment
# 287322  קליטה ב PETCT משמעה אזור עם פעילות ביולוגית גב...      comment
# 287811  \nמיותר לציין שאני בלחץ מטורף\nאני בן 37 וחי ב...         post
# 287812  שלום וברכה,\nמצטערים לא מצליחים לראות כלום. תו...      comment
#
# [669 rows x 6 columns]

# %%
data['Community'].value_counts()
# Out:
# lung cancer                 472
# hydradenitis suppurativa    197
# Name: Community, dtype: int64

# %% [markdown]
# # Data Exploration

# %%
# Number of rows
print(data.shape[0])

# Column names
print(data.columns.tolist())

# Data types
print(data.dtypes)
# Out:
# 669
# ['Date', 'Time', 'Community', 'Comment author', 'Comment', 'Post/Comment']
# Date              object
# Time              object
# Community         object
# Comment author    object
# Comment           object
# Post/Comment      object
# dtype: object

# %%
data['Community'].value_counts()
# Out:
# lung cancer                 472
# hydradenitis suppurativa    197
# Name: Community, dtype: int64

# %%
data.groupby('Community').describe()
# Out:
#                           Date                        Time                     \
#                          count unique       top freq count unique    top freq
# Community
# hydradenitis suppurativa   197    131  18/02/20    6   197    181  11:13    2
# lung cancer                472    285  14/02/17    8   472    354  10:31    5
#
#                          Comment author                                 \
#                                   count unique                top freq
# Community
# hydradenitis suppurativa            197     87  ד"ר אריאלה הפנר\n   33
# lung cancer                         472    194     ד"ר אמיר און\n  104
#
#                          Comment         \
#                            count unique
# Community
# hydradenitis suppurativa     197    196
# lung cancer                  472    469
#
#                                                                              \
#                                                                         top
# Community
# hydradenitis suppurativa  שלום לך דייב! הנה מוזמן לקרוא על כך בפירוט בקי...
# lung cancer                                                          \n\n\n
#
#                               Post/Comment
#                          freq        count unique      top freq
# Community
# hydradenitis suppurativa    2          197      2  comment  123
# lung cancer                 2          472      2  comment  297

# %%
hist1=data['Community'].hist()
hist1.set_title('Community histogram')
hist1.set_xlabel("feature value")
hist1.set_ylabel("feature amount")
# Out:
# Text(0, 0.5, 'feature amount')

# %%
import plotly.express as px
fig = px.pie(data, names='Community', title ='Pie chart of different communities of posts')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="98bbab1a-dcc0-4510-b7e4-34af4943f66e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98bbab1a-dcc0-4510-b7e4-34af4943f66e")) {                    Plotly.newPlot(                        "98bbab1a-dcc0-4510-b7e4-34af4943f66e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Community=%{label}<extra></extra>","labels":["lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung ...

# %%
# Calculate post lengths
post_len = pd.Series([len(post.split()) for post in data['Comment']])

# The distribution of tweet text lengths
post_len.plot(kind='box')

# %%
fig = plt.figure(figsize=(14,7))
data['length'] = data.Comment.str.split().apply(len)
ax1 = fig.add_subplot(122)
sns.histplot(data[data['Community']=='lung cancer']['length'], ax=ax1,color='green')
describe = data.length[data.Community=='lung cancer'].describe().to_frame().round(2)

ax2 = fig.add_subplot(121)
ax2.axis('off')
font_size = 14
bbox = [0, 0, 1, 1]
table = ax2.table(cellText = describe.values, rowLabels = describe.index, bbox=bbox, colLabels=describe.columns)
table.set_fontsize(font_size)
fig.suptitle('Distribution of text length for .', fontsize=16)

plt.show()
# Out:
# <ipython-input-14-c360206ecba6>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = plt.figure(figsize=(14,7))
data['length'] = data.Comment.str.split().apply(len)
ax1 = fig.add_subplot(122)
sns.histplot(data[data['Community']=='hydradenitis suppurativa']['length'], ax=ax1,color='blue')
describe = data.length[data.Community=='hydradenitis suppurativa'].describe().to_frame().round(2)

ax2 = fig.add_subplot(121)
ax2.axis('off')
font_size = 14
bbox = [0, 0, 1, 1]
table = ax2.table(cellText = describe.values, rowLabels = describe.index, bbox=bbox, colLabels=describe.columns)
table.set_fontsize(font_size)
fig.suptitle('Distribution of text length for .', fontsize=16)

plt.show()
# Out:
# <ipython-input-15-13485b6e8adc>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Pie

# %%
import plotly.express as px
fig = px.pie(data, names='Community', title ='Pie chart of different communities of posts')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="98bbab1a-dcc0-4510-b7e4-34af4943f66e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98bbab1a-dcc0-4510-b7e4-34af4943f66e")) {                    Plotly.newPlot(                        "98bbab1a-dcc0-4510-b7e4-34af4943f66e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Community=%{label}<extra></extra>","labels":["lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung cancer","lung ...

# %% [markdown]
# # Data Classification - basic model

# %%
data_for_basic = data.copy()

# %%
from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()

for col in ['Date', 'Time', 'Community', 'Comment author', 'Comment', 'Post/Comment']:
    data_for_basic[col] = lb.fit_transform(data_for_basic[col])

# %%
# Mute the sklearn warning
import warnings
warnings.filterwarnings('ignore', module='sklearn')

from sklearn.preprocessing import MinMaxScaler

msc = MinMaxScaler()

data_for_basic = pd.DataFrame(msc.fit_transform(data_for_basic),  # this is an np.array, not a dataframe.
                    columns=data_for_basic.columns)

# %%
# Get a list of all the columns that don't contain the label
x_cols = [x for x in data_for_basic.columns if x != 'Community']

# Split the data into two dataframes
X_data = data_for_basic[x_cols]
y_data = data_for_basic['Community']

# %%
# RK - let's check in a simple way, how much accurate is the KNN model:

def calc_acc(y_data, y_pred):
  different = 0
  for i in range(len(y_data)):
    if y_data.values[i] != y_pred[i]:
      different += 1

  print("Number of mistakes: ", different)
  mistake_per = (different/len(y_data))*100
  print("Percent of mistakes: ", mistake_per,"%")
  print("Accuracy: ", 100-mistake_per,"%")

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn = knn.fit(X_data, y_data)
y_pred = knn.predict(X_data)
calc_acc(y_data, y_pred)
# Out:
# Number of mistakes:  175
# Percent of mistakes:  26.15844544095665 %
# Accuracy:  73.84155455904335 %

# %%
lr = LogisticRegression()
lr = lr.fit(X_data, y_data)
y_pred = lr.predict(X_data)
calc_acc(y_data, y_pred)
# Out:
# Number of mistakes:  196
# Percent of mistakes:  29.297458893871447 %
# Accuracy:  70.70254110612855 %

# %% [markdown]
# # Data Pre processing

# %%
STOP_WORDS = open('/content/gdrive/MyDrive/Machine Learning course 5783/Final Project/data/heb_stopwords.txt', "r")
STOP_WORDS = STOP_WORDS.read()
STOP_WORDS = STOP_WORDS.split("\n")
print(STOP_WORDS[:10])
# Out:
# ['את', 'לא', 'של', 'אני', 'על', 'זה', 'עם', 'כל', 'הוא', 'אם']

# %%
import re
def pre_process_text(text):
    # remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # remove stop words
    text_ = [word for word in text.split() if word not in STOP_WORDS]

    # remove not hebrew letters
    my_word = re.sub(r'[^אבגדהוזחטיכלמנסעפצקרשתםןץףך]{3,}', ' ', ' '.join(text_))
    my_word2 = re.sub(r'(\s)([אבגדהוזחטיכלמנסעפצקרשתםןץףך])(\s)', ' ', my_word)

    return my_word2

# %%
basic_texts = data['Comment']
labels = data['Community']

# %%
basic_texts[:10]
# Out:
# 117136    \nבכימו והקרנות או שיש אפשרויות נוספות? תודה \...
# 117137             תלוי בשלב המחלה\nישנן אופציות נוספות\n\n
# 117138                                           כמו מה\n\n
# 117139            היי רחלה\nקיימים טיפולים ביולוגים. \n\n\n
# 117140               \nציספלטין+וינבלסטין למה לצפות? \n\n\n
# 117141     מה השאלה\nבאיזה שלב\nהאם את בטוחה שזה השילוב\n\n
# 117214    \nבבקשה לא להתנפל אבל אם אני כבר חולה כמה מזיק...
# 117215                                             מזיק\n\n
# 117216    \nשלום רב,\nאבי אובחן כחולה סרטן ריאה אדנוקרצי...
# 117217           מתאים לטיפול ביולוגי בתנאי שמפסיק לעשן\n\n
# Name: Comment, dtype: object

# %%
clean_texts = []
for text in basic_texts:
    clean_txt = pre_process_text(text)
    clean_texts.append(clean_txt)  # create pre-processed text list
# add to dataframe column with the clean text

# %%
clean_texts[:10]
# Out:
# ['בכימו והקרנות אפשרויות נוספות',
#  'תלוי המחלה ישנן אופציות נוספות',
#  '',
#  'היי רחלה קיימים טיפולים ביולוגים',
#  'ציספלטיןוינבלסטין לצפות',
#  'השאלה באיזה שלב בטוחה השילוב',
#  'להתנפל חולה מזיק להמשיך לעשן ושם',
#  'מזיק',
#  'רב אבי אובחן כחולה סרטן ריאה אדנוקרצינומה גרורות בכבד נמצאה מוטציה קיבל טיפולי כימותרפיה וצפוי לעבור כ4 טיפולים אבי הינו מעשן כבד מצליח ולהיגמל מעישון שאלתי מניעה מלנסות להיגמל בעזרת תרופות זייבן צמפקיס העישון במהלך תקופת הטיפולים הכימותרפיים מפחית מיעילותם',
#  'מתאים לטיפול ביולוגי בתנאי שמפסיק לעשן']

# %% [markdown]
# # Data Preperation - tf-idf model

# %% [markdown]
# TF-IDF (term frequency-inverse document frequency) is a method used to quantify the importance of a word in a document within a collection of documents. It is commonly used in text classification and information retrieval tasks.
#
# In the TF-IDF method, the importance of a word in a document is determined by two factors: its term frequency (TF) and its inverse document frequency (IDF). TF is the number of times a word appears in a document, and IDF is the logarithmically scaled inverse fraction of the documents that contain the word. The product of TF and IDF is the TF-IDF weight of a word in a document.
#
# Once the TF-IDF weights of all the words in a document have been calculated, they can be used as features in a machine learning classifier. Classic machine learning classifiers such as Naive Bayes, SVM, decision trees, etc. can then be trained on these features to classify texts into different categories.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ANALYZER_SIZE_LIST = [['word', 1],
                      ['word', 2], 
                      ['word', 3], 
                      #['char', 3],
                      #['char', 6],
                      #['char', 9]
                      ]

ROUND_DIGITS = 4

texts = clean_texts
number_of_texts = len(texts)
united_texts = '\n'.join(texts)
min_df=0
df_dict = {}
for analyzer, ngram_range in ANALYZER_SIZE_LIST:
    if analyzer == 'word':
        if ngram_range == 1:
            words = united_texts.split()
        else:
          words = []
          for text in texts:
            words.extend(CountVectorizer(ngram_range=(ngram_range,ngram_range)).build_analyzer()(text))
            
    elif analyzer == 'char':
        words = []
        for post in united_texts.split('\n'):
            for i in range(len(post) - ngram_range + 1):
                words.append(post[i:i + ngram_range])

    number_of_words = len(words)
    words_list = list(set(words))
    # remove empty strings from the list
    words_list = [word for word in words_list if word != '']

    new_df = pd.DataFrame(
        columns=['term', 'texts_number', 'number_in_dataset', 'tf', 'idf', 'tf-idf'])
    for word in words_list:
        number_of_texts_with_word = 0
        for text in texts:
            if word in text:
                number_of_texts_with_word += 1

        number_of_word_in_dataset = words.count(word)

        if number_of_texts_with_word >= min_df and number_of_word_in_dataset >= min_df:
            tf = number_of_word_in_dataset / number_of_words
            idf = number_of_texts / (number_of_texts_with_word + 1)
            idf = math.log(idf)
            tf_idf = tf * idf
            new_df = new_df.append(
                {'term': word,  'texts_number': number_of_texts_with_word,
                 'number_in_dataset': number_of_word_in_dataset,
                 'tf': round(tf, ROUND_DIGITS), 'idf': round(idf, ROUND_DIGITS),
                 'tf-idf': round(tf_idf, ROUND_DIGITS)}, ignore_index=True)

    df_dict[analyzer + '_' + str(ngram_range)] = new_df.sort_values(by='tf-idf', ascending=False)
    print('finished calc', analyzer, ngram_range)
# Out:
# finished calc word 1
# finished calc word 2
# finished calc word 3

# %%
df_dict['word_1']
# Out:
#         term texts_number number_in_dataset      tf     idf  tf-idf
# 1251   טיפול          193               139  0.0083  1.2379  0.0102
# 177     סרטן           88                80  0.0048  2.0171  0.0096
# 5743   המחלה           58                66  0.0039  2.4282  0.0095
# 1985   ריאות          129                88  0.0052  1.6382  0.0086
# 891   הטיפול           73                66  0.0039  2.2017  0.0086
# ...      ...          ...               ...     ...     ...     ...
# 6655     בים           69                 1  0.0001  2.2573  0.0001
# 3374     חלה           98                 1  0.0001  1.9107  0.0001
# 2885      ול          430                 1  0.0001  0.4397  0.0000
# 2431       כ          464                 1  0.0001  0.3637  0.0000
# 6563       מ          591                 1  0.0001  0.1223  0.0000
#
# [7115 rows x 6 columns]

# %%
df_dict['word_2']
# Out:
#                     term texts_number number_in_dataset      tf     idf  \
# 6738          סרטן ריאות           33                25  0.0015  2.9794
# 10095     קליטה פתולוגית            5                12  0.0007  4.7140
# 13508            דר הפנר           18                14  0.0009  3.5613
# 185             בגודל סמ            9                11  0.0007  4.2032
# 11863        לפנות לרופא           13                12  0.0007  3.8667
# ...                  ...          ...               ...     ...     ...
# 4684             דר מאיה            2                 1  0.0001  5.4072
# 6726       התפרצות המחלה            2                 1  0.0001  5.4072
# 4711             תור אצל            3                 1  0.0001  5.1195
# 12072  שינויים פיברוטיים            2                 1  0.0001  5.4072
# 11164             טי חזה           12                 1  0.0001  3.9408
#
#        tf-idf
# 6738   0.0046
# 10095  0.0035
# 13508  0.0031
# 185    0.0029
# 11863  0.0029
# ...       ...
# 4684   0.0003
# 6726   0.0003
# 4711   0.0003
# 12072  0.0003
# 11164  0.0002
#
# [14937 rows x 6 columns]

# %%
df_dict['word_3']
# Out:
#                       term texts_number number_in_dataset      tf     idf  \
# 8321           דר אמיר און            8                 8  0.0005  4.3086
# 14218     הסרת שיער בלייזר            2                 5  0.0003  5.4072
# 11774  האגודה למלחמה בסרטן            3                 5  0.0003  5.1195
# 12994     לייזר להסרת שיער            3                 4  0.0003  5.1195
# 8264           אצל דר הפנר            5                 4  0.0003  4.7140
# ...                    ...          ...               ...     ...     ...
# 702      רופא שמתמחה במחלה            2                 1  0.0001  5.4072
# 14226      רופאת העור ראתה            2                 1  0.0001  5.4072
# 519        דר חמאיסי ברמבם            2                 1  0.0001  5.4072
# 1033      מבנה צנרת הנשימה            2                 1  0.0001  5.4072
# 7202       דר מאיה גוטפריד            2                 1  0.0001  5.4072
#
#        tf-idf
# 8321   0.0022
# 14218  0.0017
# 11774  0.0016
# 12994  0.0013
# 8264   0.0012
# ...       ...
# 702    0.0003
# 14226  0.0003
# 519    0.0003
# 1033   0.0003
# 7202   0.0003
#
# [15297 rows x 6 columns]

# %% [markdown]
# # Feature selection - tf-idf model

# %% [markdown]
# ### Run for all features

# %%
TERM_NUMBER_LIST = [500, 1000, 2000, 3000, 4000, 6000, 8000, 10000]

CLASSIFIERS = {'KNN': KNeighborsClassifier(),
               'Logistic Regression': LogisticRegression(),
               'Multinomial Naive Bayes': MultinomialNB(),

               'Support Vector Machine': SVC(),
               'Desicion Tree': DecisionTreeClassifier(),

                # Bagging
               'Bagging Classifier DT - Random Forest': RandomForestClassifier(),
               'Bagging Classifier SVM': BaggingClassifier(base_estimator = SVC()),
               'Bagging Classifier LR': BaggingClassifier(base_estimator = LogisticRegression()),

               # Boosting
               'Gradient Boosting DT': GradientBoostingClassifier(),
               'Ada Boost DT': AdaBoostClassifier(),
               'Ada Boost SVM': AdaBoostClassifier(base_estimator = SVC(), algorithm='SAMME'),
               'Ada Boost LR': AdaBoostClassifier(base_estimator = LogisticRegression()),

                # Stacking
                'Stacking LR+SVC+DT+MNB': VotingClassifier(estimators = [('LR', LogisticRegression()),
                                                           ('SVC', SVC()),
                                                           ('DT', DecisionTreeClassifier()),
                                                           ('MNB', MultinomialNB())
                                                           ]),
               # Deep Learning
               'Multi-layer Perceptron': MLPClassifier(),
               }


MIN_NUMBER_OF_TEXTS = 3

# %%
def TfIdf_vectoriztion(texts, labels, model, model_name, analyze_type, size, min_text_number):
    term_number_list = [str(term) for term in TERM_NUMBER_LIST]
    model_results_dict_accuracy = {'term type': str(size) + " - " + analyze_type,
                             'model': model_name, 'measure': 'accuracy',
                             **dict.fromkeys(term_number_list, 0)}

    for terms_number in TERM_NUMBER_LIST:
        vectorizer = TfidfVectorizer(max_features=terms_number, min_df=min_text_number, analyzer=analyze_type,
                                     ngram_range=(1, size))
        response = vectorizer.fit_transform(texts)
        X, y = RandomUnderSampler().fit_resample(response, labels)
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

        # train the classifier
        model.fit(X_train, y_train)
        # predict the response for new texts
        predictions = model.predict(X_test)
        accuracy = model.score(X_test, y_test)
        precision, recall, f1, _ = precision_recall_fscore_support(y_test, predictions, average='macro')

        model_results_dict_accuracy[str(terms_number)] = round(accuracy, 8)

    return model_results_dict_accuracy

# %%
term_number_list = [str(term) for term in TERM_NUMBER_LIST]
model_results_df = pd.DataFrame(
        columns=['term type', 'model', 'measure', *term_number_list])

for analyze_type, size in ANALYZER_SIZE_LIST:
    for model_name, model in CLASSIFIERS.items():
        measuers_list = TfIdf_vectoriztion(texts, labels, model, model_name, analyze_type, size,
                                               MIN_NUMBER_OF_TEXTS)
        model_results_df = model_results_df.append(measuers_list, ignore_index=True)
        print("finished model: " + model_name + " analyzer: " + analyze_type + " " + str(
                    size) + " min text number: " + str(MIN_NUMBER_OF_TEXTS))

# create a new Excel file and add a sheet for each ngram with the results for each model
file_name = ' models results - ' + 'with min text number ' + str(MIN_NUMBER_OF_TEXTS) + '.xlsx'
# Out:
# finished model: KNN analyzer: word 1 min text number: 3
# finished model: Logistic Regression analyzer: word 1 min text number: 3
# finished model: Multinomial Naive Bayes analyzer: word 1 min text number: 3
# finished model: Support Vector Machine analyzer: word 1 min text number: 3
# finished model: Desicion Tree analyzer: word 1 min text number: 3
# finished model: Bagging Classifier DT - Random Forest analyzer: word 1 min text number: 3
# finished model: Bagging Classifier SVM analyzer: word 1 min text number: 3
# finished model: Bagging Classifier LR analyzer: word 1 min text number: 3
# finished model: Gradient Boosting DT analyzer: word 1 min text number: 3
# finished model: Ada Boost DT analyzer: word 1 min text number: 3
# finished model: Ada Boost SVM analyzer: word 1 min text number: 3
# finished model: Ada Boost LR analyzer: word 1 min text number: 3
# finished model: Stacking LR+SVC+DT+MNB analyzer: word 1 min text number: 3
# finished model: Multi-layer Perceptron analyzer: word 1 min text number: 3
# finished model: KNN analyzer: word 2 min text number: 3
# finished model: Logistic Regression analyzer: word 2 min text number: 3
# finished model: Multinomial Naive Bayes analyzer: word 2 min text number: 3
# finished model: Support Vector Machine analyzer: word 2 min text number: 3
# finished model: Desicion Tree analyzer: word 2 min text number: 3
# finished model: Bagging Classifier DT - Random Forest analyzer: word 2 min text number: 3
# finished model: Bagging Classifier SVM analyzer: word 2 min text number: 3
# finished model: Bagging Classifier LR analyzer: word 2 min text number: 3
# finished model: Gradient Boosting DT analyzer: word 2 min text number: 3
# finished model: Ada Boost DT analyzer: word 2 min text number: 3
# finished model: Ada Boost SVM analyzer: word 2 min text number: 3
# finished model: Ada Boost LR analyzer: word 2 min text number: 3
# finished model: Stacking LR+SVC+DT+MNB analyzer: word 2 min text number: 3
# finished model: Multi-layer Perceptron analyzer: word 2 min text number: 3
# finished model: KNN analyzer: word 3 min text number: 3
# finished model: Logistic Regression analyzer: word 3 min text number: 3
# finished model: Multinomial Naive Bayes analyzer: word 3 min text number: 3
# finished model: Support Vector Machine analyzer: word 3 min text number: 3
# finished model: Desicion Tree analyzer: word 3 min text number: 3
# finished model: Bagging Classifier DT - Random Forest analyzer: word 3 min text number: 3
# finished model: Bagging Classifier SVM analyzer: word 3 min text number: 3
# finished model: Bagging Classifier LR analyzer: word 3 min text number: 3
# finished model: Gradient Boosting DT analyzer: word 3 min text number: 3
# finished model: Ada Boost DT analyzer: word 3 min text number: 3
# finished model: Ada Boost SVM analyzer: word 3 min text number: 3
# finished model: Ada Boost LR analyzer: word 3 min text number: 3
# finished model: Stacking LR+SVC+DT+MNB analyzer: word 3 min text number: 3
# finished model: Multi-layer Perceptron analyzer: word 3 min text number: 3

# %%
model_results_df
# Out:
#    term type                                  model   measure       500  \
# 0   1 - word                                    KNN  accuracy  0.444444
# 1   1 - word                    Logistic Regression  accuracy  0.818182
# 2   1 - word                Multinomial Naive Bayes  accuracy  0.878788
# 3   1 - word                 Support Vector Machine  accuracy  0.767677
# 4   1 - word                          Desicion Tree  accuracy  0.777778
# 5   1 - word  Bagging Classifier DT - Random Forest  accuracy  0.777778
# 6   1 - word                 Bagging Classifier SVM  accuracy  0.787879
# 7   1 - word                  Bagging Classifier LR  accuracy  0.797980
# 8   1 - word                   Gradient Boosting DT  accuracy  0.686869
# 9   1 - word                           Ada Boost DT  accuracy  0.777778
# 10  1 - word                          Ada Boost SVM  accuracy  0.424242
# 11  1 - word                           Ada Boost LR  accuracy  0.747475
# 12  1 - word                 Stacking LR+SVC+DT+MNB  accuracy  0.848485
# 13  1 - word                 Multi-layer Perceptron  accuracy  0.797980
# 14  2 - word                                    KNN  accuracy  0.424242
# 15  2 - word                    Logistic Regression  accuracy  0.777778
# 16  2 - word                Multinomial Naive Bayes  accuracy  0.858586
# 17  2 - word                 Support Vector Machine  accuracy  0.757576
# 18  2 - word                          Desicion Tree  accuracy  0.686869
# 19  2 - word  Bagging Classifier DT - Random Forest  accuracy  0.818182
# 20  2 - word                 Bagging Classifier SVM  accuracy  0.828283
# 21  2 - word                  Bagging Classifier LR  accuracy  0.777778
# 22  2 - word                   Gradient Boosting DT  accuracy  0.767677
# 23  2 - word                           Ada Boost DT  accuracy  0.747475
# 24  2 - word                          Ada Boost SVM  accuracy  0.424242
# 25  2 - word                           Ada Boost LR  accuracy  0.747475
# 26  2 - word                 Stacking LR+SVC+DT+MNB  accuracy  0.818182
# 27  2 - word                 Multi-layer Perceptron  accuracy  0.808081
# 28  3 - word                                    KNN  accuracy  0.494949
# 29  3 - word                    Logistic Regression  accuracy  0.797980
# 30  3 - word                Multinomial Naive Bayes  accuracy  0.838384
# 31  3 - word                 Support Vector Machine  accuracy  0.838384
# 32  3 - word                          Desicion Tree  accuracy  0.727273
# 33  3 - word  Bagging Classifier DT - Random Forest  accuracy  0.777778
# 34  3 - word                 Bagging Classifier SVM  accuracy  0.797980
# 35  3 - word                  Bagging Classifier LR  accuracy  0.808081
# 36  3 - word                   Gradient Boosting DT  accuracy  0.747475
# 37  3 - word                           Ada Boost DT  accuracy  0.717172
# 38  3 - word                          Ada Boost SVM  accuracy  0.424242
# 39  3 - word                           Ada Boost LR  accuracy  0.757576
# 40  3 - word                 Stacking LR+SVC+DT+MNB  accuracy  0.777778
# 41  3 - word                 Multi-layer Perceptron  accuracy  0.808081
#
#         1000      2000      3000      4000      6000      8000     10000
# 0   0.393939  0.444444  0.515152  0.404040  0.434343  0.424242  0.424242
# 1   0.818182  0.828283  0.818182  0.838384  0.818182  0.818182  0.777778
# 2   0.858586  0.888889  0.888889  0.878788  0.868687  0.878788  0.909091
# 3   0.808081  0.878788  0.828283  0.797980  0.828283  0.858586  0.767677
# 4   0.757576  0.707071  0.696970  0.717172  0.646465  0.727273  0.727273
# 5   0.737374  0.757576  0.767677  0.777778  0.757576  0.818182  0.777778
# 6   0.868687  0.818182  0.808081  0.808081  0.808081  0.848485  0.787879
# 7   0.787879  0.808081  0.818182  0.818182  0.818182  0.818182  0.818182
# 8   0.747475  0.767677  0.737374  0.797980  0.727273  0.767677  0.747475
# 9   0.717172  0.707071  0.696970  0.717172  0.707071  0.747475  0.707071
# 10  0.424242  0.424242  0.424242  0.424242  0.424242  0.424242  0.424242
# 11  0.737374  0.696970  0.727273  0.707071  0.686869  0.727273  0.717172
# 12  0.818182  0.828283  0.808081  0.777778  0.818182  0.808081  0.777778
# 13  0.808081  0.808081  0.787879  0.818182  0.858586  0.848485  0.838384
# 14  0.434343  0.454545  0.454545  0.454545  0.424242  0.444444  0.424242
# 15  0.818182  0.818182  0.818182  0.797980  0.787879  0.797980  0.818182
# 16  0.828283  0.909091  0.898990  0.909091  0.858586  0.848485  0.848485
# 17  0.787879  0.787879  0.818182  0.848485  0.797980  0.787879  0.767677
# 18  0.717172  0.717172  0.737374  0.717172  0.777778  0.737374  0.707071
# 19  0.757576  0.777778  0.777778  0.737374  0.797980  0.757576  0.787879
# 20  0.828283  0.818182  0.838384  0.838384  0.818182  0.797980  0.808081
# 21  0.797980  0.797980  0.787879  0.747475  0.767677  0.787879  0.828283
# 22  0.747475  0.727273  0.737374  0.727273  0.757576  0.757576  0.727273
# 23  0.767677  0.696970  0.737374  0.696970  0.727273  0.676768  0.676768
# 24  0.424242  0.424242  0.424242  0.424242  0.424242  0.424242  0.424242
# 25  0.737374  0.727273  0.707071  0.737374  0.737374  0.717172  0.737374
# 26  0.797980  0.828283  0.898990  0.808081  0.838384  0.808081  0.818182
# 27  0.818182  0.818182  0.818182  0.888889  0.858586  0.888889  0.898990
# 28  0.454545  0.484848  0.404040  0.444444  0.424242  0.454545  0.424242
# 29  0.797980  0.797980  0.818182  0.787879  0.787879  0.828283  0.808081
# 30  0.878788  0.909091  0.858586  0.868687  0.878788  0.858586  0.909091
# 31  0.797980  0.787879  0.797980  0.848485  0.797980  0.838384  0.777778
# 32  0.717172  0.737374  0.727273  0.737374  0.727273  0.757576  0.727273
# 33  0.797980  0.797980  0.727273  0.767677  0.727273  0.777778  0.767677
# 34  0.777778  0.818182  0.828283  0.858586  0.848485  0.787879  0.888889
# 35  0.818182  0.787879  0.797980  0.808081  0.787879  0.767677  0.808081
# 36  0.727273  0.737374  0.747475  0.737374  0.717172  0.727273  0.727273
# 37  0.727273  0.757576  0.737374  0.717172  0.757576  0.757576  0.707071
# 38  0.424242  0.424242  0.424242  0.424242  0.424242  0.424242  0.424242
# 39  0.747475  0.686869  0.727273  0.727273  0.727273  0.727273  0.707071
# 40  0.848485  0.828283  0.797980  0.858586  0.818182  0.858586  0.838384
# 41  0.838384  0.818182  0.838384  0.808081  0.818182  0.878788  0.909091

# %% [markdown]
# ### Choose best max features for every row (analyzer and classifier)

# %%
df = model_results_df
columns_of_results = len(TERM_NUMBER_LIST)
# select the last 4 columns
last_4_cols = model_results_df.iloc[:, -1*columns_of_results:]

# find the column name of the max value in each row
max_col = last_4_cols.idxmax(axis=1)

# find the max value in each row
max_val = last_4_cols.max(axis=1)

# create a new dataframe with all columns except the last 4
new_model_results_df = model_results_df.iloc[:, :-1*columns_of_results]

# add the max value and column name as new columns
new_model_results_df['max measure'] = max_val
new_model_results_df['max features'] = max_col

# %%
new_model_results_df.sort_values(by='max measure', ascending=False)
# Out:
#    term type                                  model   measure  max measure  \
# 41  3 - word                 Multi-layer Perceptron  accuracy     0.909091
# 2   1 - word                Multinomial Naive Bayes  accuracy     0.909091
# 30  3 - word                Multinomial Naive Bayes  accuracy     0.909091
# 16  2 - word                Multinomial Naive Bayes  accuracy     0.909091
# 27  2 - word                 Multi-layer Perceptron  accuracy     0.898990
# 26  2 - word                 Stacking LR+SVC+DT+MNB  accuracy     0.898990
# 34  3 - word                 Bagging Classifier SVM  accuracy     0.888889
# 3   1 - word                 Support Vector Machine  accuracy     0.878788
# 6   1 - word                 Bagging Classifier SVM  accuracy     0.868687
# 40  3 - word                 Stacking LR+SVC+DT+MNB  accuracy     0.858586
# 13  1 - word                 Multi-layer Perceptron  accuracy     0.858586
# 31  3 - word                 Support Vector Machine  accuracy     0.848485
# 17  2 - word                 Support Vector Machine  accuracy     0.848485
# 12  1 - word                 Stacking LR+SVC+DT+MNB  accuracy     0.848485
# 1   1 - word                    Logistic Regression  accuracy     0.838384
# 20  2 - word                 Bagging Classifier SVM  accuracy     0.838384
# 29  3 - word                    Logistic Regression  accuracy     0.828283
# 21  2 - word                  Bagging Classifier LR  accuracy     0.828283
# 15  2 - word                    Logistic Regression  accuracy     0.818182
# 35  3 - word                  Bagging Classifier LR  accuracy     0.818182
# 5   1 - word  Bagging Classifier DT - Random Forest  accuracy     0.818182
# 7   1 - word                  Bagging Classifier LR  accuracy     0.818182
# 19  2 - word  Bagging Classifier DT - Random Forest  accuracy     0.818182
# 8   1 - word                   Gradient Boosting DT  accuracy     0.797980
# 33  3 - word  Bagging Classifier DT - Random Forest  accuracy     0.797980
# 9   1 - word                           Ada Boost DT  accuracy     0.777778
# 4   1 - word                          Desicion Tree  accuracy     0.777778
# 18  2 - word                          Desicion Tree  accuracy     0.777778
# 23  2 - word                           Ada Boost DT  accuracy     0.767677
# 22  2 - word                   Gradient Boosting DT  accuracy     0.767677
# 32  3 - word                          Desicion Tree  accuracy     0.757576
# 37  3 - word                           Ada Boost DT  accuracy     0.757576
# 39  3 - word                           Ada Boost LR  accuracy     0.757576
# 11  1 - word                           Ada Boost LR  accuracy     0.747475
# 25  2 - word                           Ada Boost LR  accuracy     0.747475
# 36  3 - word                   Gradient Boosting DT  accuracy     0.747475
# 0   1 - word                                    KNN  accuracy     0.515152
# 28  3 - word                                    KNN  accuracy     0.494949
# 14  2 - word                                    KNN  accuracy     0.454545
# 10  1 - word                          Ada Boost SVM  accuracy     0.424242
# 24  2 - word                          Ada Boost SVM  accuracy     0.424242
# 38  3 - word                          Ada Boost SVM  accuracy     0.424242
#
#    max features
# 41        10000
# 2         10000
# 30         2000
# 16         2000
# 27        10000
# 26         3000
# 34        10000
# 3          2000
# 6          1000
# 40         4000
# 13         6000
# 31         4000
# 17         4000
# 12          500
# 1          4000
# 20         3000
# 29         8000
# 21        10000
# 15         1000
# 35         1000
# 5          8000
# 7          3000
# 19          500
# 8          4000
# 33         1000
# 9           500
# 4           500
# 18         6000
# 23         1000
# 22          500
# 32         8000
# 37         2000
# 39          500
# 11          500
# 25          500
# 36          500
# 0          3000
# 28          500
# 14         2000
# 10          500
# 24          500
# 38          500

# %% [markdown]
# # Parameter Tuning for the best models - tf-idf model

# %%
def get_best_parameters(classifier, X_train, y_train):
    # create a dictionary with the parameters to test
    classifier_name = classifier.__class__.__name__
    parameters={}
    if classifier_name == 'LogisticRegression':
        parameters = {'C': [0.1, 1, 10],
                      'penalty': ['l1', 'l2', 'elasticnet'],
                      'solver': ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
                      'max_iter': [1000]
                      }
    elif classifier_name == 'SVC':
        parameters = {'C': [0.1, 1, 10],
                      'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
                      'gamma': ['scale', 'auto'],
                      'degree': [1,2,3],
                      'max_iter': [1000]
                      }
    elif classifier_name == 'RandomForestClassifier':
        parameters = {'n_estimators': [50, 100, 200],
                      'criterion': ['gini', 'entropy'],
                      'max_depth': [None, 10, 50, 100],
                      'max_features': [1, 10, 100, 'sqrt', 'log2']
                    }                 
    elif classifier_name == 'MLPClassifier':
        parameters = {'hidden_layer_sizes': [(1,), (10,), (100,)],
                      'activation': ['logistic', 'tanh', 'relu'],
                      'solver': ['lbfgs', 'sgd', 'adam'],
                      'alpha': [0.001, 0.01],
                      'max_iter': [1000],
                      'early_stopping': [True]
                      }
    elif classifier_name == 'KNeighborsClassifier':
        parameters = {'n_neighbors': [1, 11, 101],
                      'weights': ['uniform', 'distance'],
                      'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
                      }
    elif classifier_name == 'DecisionTreeClassifier':
        parameters = {'criterion': ['gini', 'entropy'],
                      'splitter': ['best', 'random'],
                      'max_depth': [None, 10, 50, 100],
                      'max_features': [1, 10, 100, 'sqrt', 'log2']
                      }
    elif classifier_name == 'MultinomialNB':
        parameters = {'alpha': [0.01, 0.1, 1, 10],
                      'fit_prior': [True, False]
                      }
    elif classifier_name == 'AdaBoostClassifier':
        parameters = {'n_estimators': [50, 100, 200],
                      'learning_rate': [0.01, 0.1]
                      }
    elif classifier_name == 'BaggingClassifier':
        parameters = {'n_estimators': [50, 100, 200],
                      'max_samples': [None, 0.5, 0.7],
                      'max_features': [None, 0.5, 0.7],
                      'n_jobs': [-1]
                      }
    elif classifier_name == 'GradientBoostingClassifier':
        parameters = { 'loss': ['log_loss', 'deviance', 'exponential'],
                'learning_rate': [0.001, 0.1],
                "max_features":["log2","sqrt"],
                "n_estimators":[50, 100, 200]}
    elif classifier_name =='VotingClassifier':
      parameters = { 'voting': ['hard', 'soft'],
                     'n_jobs': [-1]       
                    }
                
    # create a grid search object and fit it to the data
    grid_obj = GridSearchCV(estimator=classifier, 
                            param_grid=parameters, 
                            scoring='accuracy',
                            cv=5, 
                            verbose=2, 
                            n_jobs = -1
                            )
    grid_obj = grid_obj.fit(X_train, y_train)

    # return best parameters
    return grid_obj.best_params_, grid_obj.best_estimator_

# %%
def measure_error(y_true, y_pred, label):
    return pd.Series({'accuracy': round(accuracy_score(y_true, y_pred), 4),
                      'precision': round(precision_score(y_true, y_pred, average = 'weighted'), 4),
                      'recall': round(recall_score(y_true, y_pred, average = 'weighted'), 4),
                      'f1': round(f1_score(y_true, y_pred, average = 'weighted'), 4)},
                      name=label)

# %%
def TfIdf_vectoriztion_with_grid_search(texts, labels, model, model_name, analyze_type, size, min_text_number, terms_number):
    vectorizer = TfidfVectorizer(max_features=terms_number, min_df=min_text_number, analyzer=analyze_type,
                                     ngram_range=(1, size))
    response = vectorizer.fit_transform(texts)

    best_params, best_classifier = get_best_parameters(model, response, labels)

    X, y = RandomUnderSampler().fit_resample(response, labels)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

    model.fit(X_train, y_train)
    y_train_pred_gr = best_classifier.predict(X_train)
    y_test_pred_gr = best_classifier.predict(X_test)

    from sklearn.metrics import roc_curve, precision_recall_curve, confusion_matrix, ConfusionMatrixDisplay
    cm = confusion_matrix(y_test, y_test_pred_gr, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)

    measures1 = measure_error(y_train, y_train_pred_gr, 'train')
    measures2 = measure_error(y_test, y_test_pred_gr, 'test')

    
    return best_params, measures1, measures2, cm, disp, model

# %%
best_params_list = []
best_accuracy_train  = []
best_accuracy_test = []
best_precision_train = []
best_precision_test  = []
best_recall_train = []
best_recall_test = []
best_f1_train  = []
best_f1_test = []
conf_matrices = []
conf_matrices_display = []
models = []

for index, row in new_model_results_df.iterrows():
  
    model_name = row['model']
    model = CLASSIFIERS[model_name]
    term_type = row['term type'].split(" - ")

    analyze_type = term_type[1]
    size = int(term_type[0])
    terms_number = int(row['max features'])

    print(model_name)

    best_params, measures_train, measures_test, cm, disp, model = TfIdf_vectoriztion_with_grid_search(texts, labels, model, model_name, analyze_type, size,
                                               MIN_NUMBER_OF_TEXTS, terms_number)
    best_params_list.append(best_params)
    best_accuracy_train.append(measures_train['accuracy'])
    best_accuracy_test.append(measures_test['accuracy'])
    best_precision_train.append(measures_train['precision'])
    best_precision_test.append(measures_test['precision'])
    best_recall_train.append(measures_train['recall'])
    best_recall_test.append(measures_test['recall'])
    best_f1_train.append(measures_train['f1'])
    best_f1_test.append(measures_test['f1'])
    conf_matrices.append(cm)
    conf_matrices_display.append(disp)
    models.append(model)


new_model_results_df['best params'] = best_params_list
new_model_results_df['best accuracy train'] = best_accuracy_train
new_model_results_df['best accuracy test'] = best_accuracy_test
new_model_results_df['best precision train'] = best_precision_train
new_model_results_df['best precision test'] = best_precision_test
new_model_results_df['best recall train'] = best_recall_train
new_model_results_df['best recall test'] = best_recall_test
new_model_results_df['best f1 train'] = best_f1_train
new_model_results_df['best f1 test'] = best_f1_test
new_model_results_df['conf matrices'] = conf_matrices
new_model_results_df['conf matrices display'] = conf_matrices_display
new_model_results_df['model'] = models
# Out:
# KNN
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Logistic Regression
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Multinomial Naive Bayes
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Support Vector Machine
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Desicion Tree
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Bagging Classifier DT - Random Forest
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# Bagging Classifier SVM
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Bagging Classifier LR
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Gradient Boosting DT
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Ada Boost DT
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Ada Boost SVM
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Ada Boost LR
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Stacking LR+SVC+DT+MNB
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Multi-layer Perceptron
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# KNN
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Logistic Regression
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Multinomial Naive Bayes
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Support Vector Machine
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Desicion Tree
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Bagging Classifier DT - Random Forest
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# Bagging Classifier SVM
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Bagging Classifier LR
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Gradient Boosting DT
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Ada Boost DT
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Ada Boost SVM
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Ada Boost LR
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Stacking LR+SVC+DT+MNB
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Multi-layer Perceptron
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# KNN
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Logistic Regression
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Multinomial Naive Bayes
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Support Vector Machine
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Desicion Tree
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Bagging Classifier DT - Random Forest
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# Bagging Classifier SVM
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Bagging Classifier LR
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Gradient Boosting DT
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Ada Boost DT
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Ada Boost SVM
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Ada Boost LR
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Stacking LR+SVC+DT+MNB
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Multi-layer Perceptron
# Fitting 5 folds for each of 54 candidates, totalling 270 fits

# %%
new_model_results_df.drop('conf matrices', axis=1).drop('conf matrices display', axis=1).drop('model', axis=1)
# Out:
#    term type   measure  max measure max features  \
# 0   1 - word  accuracy     0.515152         3000
# 1   1 - word  accuracy     0.838384         4000
# 2   1 - word  accuracy     0.909091        10000
# 3   1 - word  accuracy     0.878788         2000
# 4   1 - word  accuracy     0.777778          500
# 5   1 - word  accuracy     0.818182         8000
# 6   1 - word  accuracy     0.868687         1000
# 7   1 - word  accuracy     0.818182         3000
# 8   1 - word  accuracy     0.797980         4000
# 9   1 - word  accuracy     0.777778          500
# 10  1 - word  accuracy     0.424242          500
# 11  1 - word  accuracy     0.747475          500
# 12  1 - word  accuracy     0.848485          500
# 13  1 - word  accuracy     0.858586         6000
# 14  2 - word  accuracy     0.454545         2000
# 15  2 - word  accuracy     0.818182         1000
# 16  2 - word  accuracy     0.909091         2000
# 17  2 - word  accuracy     0.848485         4000
# 18  2 - word  accuracy     0.777778         6000
# 19  2 - word  accuracy     0.818182          500
# 20  2 - word  accuracy     0.838384         3000
# 21  2 - word  accuracy     0.828283        10000
# 22  2 - word  accuracy     0.767677          500
# 23  2 - word  accuracy     0.767677         1000
# 24  2 - word  accuracy     0.424242          500
# 25  2 - word  accuracy     0.747475          500
# 26  2 - word  accuracy     0.898990         3000
# 27  2 - word  accuracy     0.898990        10000
# 28  3 - word  accuracy     0.494949          500
# 29  3 - word  accuracy     0.828283         8000
# 30  3 - word  accuracy     0.909091         2000
# 31  3 - word  accuracy     0.848485         4000
# 32  3 - word  accuracy     0.757576         8000
# 33  3 - word  accuracy     0.797980         1000
# 34  3 - word  accuracy     0.888889        10000
# 35  3 - word  accuracy     0.818182         1000
# 36  3 - word  accuracy     0.747475          500
# 37  3 - word  accuracy     0.757576         2000
# 38  3 - word  accuracy     0.424242          500
# 39  3 - word  accuracy     0.757576          500
# 40  3 - word  accuracy     0.858586         4000
# 41  3 - word  accuracy     0.909091        10000
#
#                                           best params  best accuracy train  \
# 0   {'algorithm': 'auto', 'n_neighbors': 101, 'wei...               0.5932
# 1   {'C': 10, 'max_iter': 1000, 'penalty': 'l2', '...               0.9898
# 2                   {'alpha': 0.1, 'fit_prior': True}               0.9831
# 3   {'C': 1, 'degree': 1, 'gamma': 'scale', 'kerne...               0.9729
# 4   {'criterion': 'entropy', 'max_depth': 50, 'max...               0.9627
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...               0.9898
# 6   {'max_features': 0.7, 'max_samples': 0.7, 'n_e...               0.8949
# 7   {'max_features': 0.7, 'max_samples': 0.7, 'n_e...               0.6034
# 8   {'learning_rate': 0.1, 'loss': 'exponential', ...               0.9017
# 9         {'learning_rate': 0.1, 'n_estimators': 100}               0.8712
# 10        {'learning_rate': 0.01, 'n_estimators': 50}               0.5254
# 11        {'learning_rate': 0.01, 'n_estimators': 50}               0.5254
# 12                   {'n_jobs': -1, 'voting': 'hard'}               0.9661
# 13  {'activation': 'tanh', 'alpha': 0.001, 'early_...               0.9898
# 14  {'algorithm': 'auto', 'n_neighbors': 101, 'wei...               0.5966
# 15  {'C': 10, 'max_iter': 1000, 'penalty': 'l2', '...               0.9864
# 16                  {'alpha': 0.1, 'fit_prior': True}               0.9831
# 17  {'C': 1, 'degree': 1, 'gamma': 'scale', 'kerne...               0.9763
# 18  {'criterion': 'gini', 'max_depth': 50, 'max_fe...               0.9661
# 19  {'criterion': 'entropy', 'max_depth': None, 'm...               0.9661
# 20  {'max_features': 0.7, 'max_samples': 0.7, 'n_e...               0.8746
# 21  {'max_features': 0.7, 'max_samples': 0.7, 'n_e...               0.6169
# 22  {'learning_rate': 0.1, 'loss': 'exponential', ...               0.8915
# 23        {'learning_rate': 0.1, 'n_estimators': 200}               0.9864
# 24        {'learning_rate': 0.01, 'n_estimators': 50}               0.5254
# 25        {'learning_rate': 0.01, 'n_estimators': 50}               0.5254
# 26                   {'n_jobs': -1, 'voting': 'hard'}               0.9864
# 27  {'activation': 'logistic', 'alpha': 0.001, 'ea...               0.9898
# 28  {'algorithm': 'auto', 'n_neighbors': 101, 'wei...               0.5627
# 29  {'C': 10, 'max_iter': 1000, 'penalty': 'l2', '...               0.9898
# 30                  {'alpha': 0.1, 'fit_prior': True}               0.9831
# 31  {'C': 1, 'degree': 1, 'gamma': 'scale', 'kerne...               0.9763
# 32  {'criterion': 'entropy', 'max_depth': 100, 'ma...               0.9898
# 33  {'criterion': 'entropy', 'max_depth': None, 'm...               0.9898
# 34  {'max_features': 0.7, 'max_samples': 0.7, 'n_e...               0.8881
# 35  {'max_features': 0.7, 'max_samples': 0.7, 'n_e...               0.6508
# 36  {'learning_rate': 0.1, 'loss': 'deviance', 'ma...               0.9220
# 37        {'learning_rate': 0.1, 'n_estimators': 200}               0.9797
# 38        {'learning_rate': 0.01, 'n_estimators': 50}               0.5254
# 39        {'learning_rate': 0.01, 'n_estimators': 50}               0.5254
# 40                   {'n_jobs': -1, 'voting': 'hard'}               0.9898
# 41  {'activation': 'logistic', 'alpha': 0.01, 'ear...               0.9898
#
#     best accuracy test  best precision train  best precision test  \
# 0               0.5152                0.7707               0.7737
# 1               0.9899                0.9900               0.9901
# 2               0.9798                0.9836               0.9807
# 3               0.9798                0.9742               0.9807
# 4               0.9293                0.9652               0.9348
# 5               0.9899                0.9900               0.9901
# 6               0.8081                0.9124               0.8679
# 7               0.4848                0.7740               0.7674
# 8               0.8687                0.9172               0.8997
# 9               0.8081                0.8965               0.8679
# 10              0.4242                0.2761               0.1800
# 11              0.4242                0.2761               0.1800
# 12              0.9293                0.9668               0.9348
# 13              0.9899                0.9900               0.9901
# 14              0.5152                0.7718               0.7737
# 15              0.9596                0.9868               0.9631
# 16              0.9798                0.9832               0.9807
# 17              0.9798                0.9773               0.9807
# 18              0.8889                0.9682               0.9119
# 19              0.9495                0.9668               0.9549
# 20              0.8182                0.8987               0.8727
# 21              0.4949                0.7785               0.7694
# 22              0.8788                0.9101               0.9057
# 23              0.9596                0.9868               0.9631
# 24              0.4242                0.2761               0.1800
# 25              0.4242                0.2761               0.1800
# 26              0.9798                0.9868               0.9807
# 27              0.9899                0.9900               0.9901
# 28              0.4646                0.7613               0.7633
# 29              0.9899                0.9900               0.9901
# 30              0.9798                0.9832               0.9807
# 31              0.9798                0.9773               0.9807
# 32              0.9899                0.9900               0.9901
# 33              0.9596                0.9900               0.9631
# 34              0.8384                0.9078               0.8830
# 35              0.5758                0.7902               0.7879
# 36              0.9091                0.9321               0.9251
# 37              0.9798                0.9804               0.9807
# 38              0.4242                0.2761               0.1800
# 39              0.4242                0.2761               0.1800
# 40              0.9798                0.9900               0.9807
# 41              0.9899                0.9900               0.9901
#
#     best recall train  best recall test  best f1 train  best f1 test
# 0              0.5932            0.5152         0.4974        0.4270
# 1              0.9898            0.9899         0.9898        0.9899
# 2              0.9831            0.9798         0.9830        0.9799
# 3              0.9729            0.9798         0.9728        0.9799
# 4              0.9627            0.9293         0.9626        0.9297
# 5              0.9898            0.9899         0.9898        0.9899
# 6              0.8949            0.8081         0.8932        0.8066
# 7              0.6034            0.4848         0.5154        0.3736
# 8              0.9017            0.8687         0.9002        0.8690
# 9              0.8712            0.8081         0.8681        0.8066
# 10             0.5254            0.4242         0.3620        0.2527
# 11             0.5254            0.4242         0.3620        0.2527
# 12             0.9661            0.9293         0.9661        0.9297
# 13             0.9898            0.9899         0.9898        0.9899
# 14             0.5966            0.5152         0.5035        0.4270
# 15             0.9864            0.9596         0.9864        0.9598
# 16             0.9831            0.9798         0.9830        0.9799
# 17             0.9763            0.9798         0.9762        0.9799
# 18             0.9661            0.8889         0.9660        0.8894
# 19             0.9661            0.9495         0.9661        0.9498
# 20             0.8746            0.8182         0.8717        0.8172
# 21             0.6169            0.4949         0.5385        0.3919
# 22             0.8915            0.8788         0.8896        0.8792
# 23             0.9864            0.9596         0.9864        0.9598
# 24             0.5254            0.4242         0.3620        0.2527
# 25             0.5254            0.4242         0.3620        0.2527
# 26             0.9864            0.9798         0.9864        0.9799
# 27             0.9898            0.9899         0.9898        0.9899
# 28             0.5627            0.4646         0.4402        0.3356
# 29             0.9898            0.9899         0.9898        0.9899
# 30             0.9831            0.9798         0.9830        0.9799
# 31             0.9763            0.9798         0.9762        0.9799
# 32             0.9898            0.9899         0.9898        0.9899
# 33             0.9898            0.9596         0.9898        0.9598
# 34             0.8881            0.8384         0.8860        0.8381
# 35             0.6508            0.5758         0.5928        0.5227
# 36             0.9220            0.9091         0.9212        0.9096
# 37             0.9797            0.9798         0.9796        0.9799
# 38             0.5254            0.4242         0.3620        0.2527
# 39             0.5254            0.4242         0.3620        0.2527
# 40             0.9898            0.9798         0.9898        0.9799
# 41             0.9898            0.9899         0.9898        0.9899

# %%
for index, row in new_model_results_df.iterrows():
  row['conf matrices display'].plot()

# %%
cm = new_model_results_df['conf matrices'][1]
sns.heatmap(cm/np.sum(cm),annot = True, fmt='.2%', cmap='Blues')

# %% [markdown]
# # **Conclusions**

# %%
new_model_results_df.iloc[: , :8].sort_values(by='best accuracy test', ascending=False)
# Out:
#    term type                                              model   measure  \
# 41  3 - word                                    MLPClassifier()  accuracy
# 13  1 - word                                    MLPClassifier()  accuracy
# 29  3 - word                               LogisticRegression()  accuracy
# 32  3 - word                           DecisionTreeClassifier()  accuracy
# 27  2 - word                                    MLPClassifier()  accuracy
# 5   1 - word  (DecisionTreeClassifier(max_features='auto', r...  accuracy
# 1   1 - word                               LogisticRegression()  accuracy
# 26  2 - word  VotingClassifier(estimators=[('LR', LogisticRe...  accuracy
# 17  2 - word                                              SVC()  accuracy
# 16  2 - word                                    MultinomialNB()  accuracy
# 31  3 - word                                              SVC()  accuracy
# 30  3 - word                                    MultinomialNB()  accuracy
# 40  3 - word  VotingClassifier(estimators=[('LR', LogisticRe...  accuracy
# 2   1 - word                                    MultinomialNB()  accuracy
# 37  3 - word  (DecisionTreeClassifier(max_depth=1, random_st...  accuracy
# 3   1 - word                                              SVC()  accuracy
# 23  2 - word  (DecisionTreeClassifier(max_depth=1, random_st...  accuracy
# 33  3 - word  (DecisionTreeClassifier(max_features='auto', r...  accuracy
# 15  2 - word                               LogisticRegression()  accuracy
# 19  2 - word  (DecisionTreeClassifier(max_features='auto', r...  accuracy
# 4   1 - word                           DecisionTreeClassifier()  accuracy
# 12  1 - word  VotingClassifier(estimators=[('LR', LogisticRe...  accuracy
# 36  3 - word  ([DecisionTreeRegressor(criterion='friedman_ms...  accuracy
# 18  2 - word                           DecisionTreeClassifier()  accuracy
# 22  2 - word  ([DecisionTreeRegressor(criterion='friedman_ms...  accuracy
# 8   1 - word  ([DecisionTreeRegressor(criterion='friedman_ms...  accuracy
# 34  3 - word  (SVC(random_state=316854418), SVC(random_state...  accuracy
# 20  2 - word  (SVC(random_state=316854418), SVC(random_state...  accuracy
# 6   1 - word  (SVC(random_state=316854418), SVC(random_state...  accuracy
# 9   1 - word  (DecisionTreeClassifier(max_depth=1, random_st...  accuracy
# 35  3 - word  (LogisticRegression(random_state=248826902), L...  accuracy
# 0   1 - word                             KNeighborsClassifier()  accuracy
# 14  2 - word                             KNeighborsClassifier()  accuracy
# 21  2 - word  (LogisticRegression(random_state=248826902), L...  accuracy
# 7   1 - word  (LogisticRegression(random_state=248826902), L...  accuracy
# 28  3 - word                             KNeighborsClassifier()  accuracy
# 25  2 - word  (LogisticRegression(random_state=773999003), L...  accuracy
# 24  2 - word  (SVC(random_state=1489459545), SVC(random_stat...  accuracy
# 11  1 - word  (LogisticRegression(random_state=773999003), L...  accuracy
# 10  1 - word  (SVC(random_state=1489459545), SVC(random_stat...  accuracy
# 38  3 - word  (SVC(random_state=1489459545), SVC(random_stat...  accuracy
# 39  3 - word  (LogisticRegression(random_state=773999003), L...  accuracy
#
#     max measure max features  \
# 41     0.909091        10000
# 13     0.858586         6000
# 29     0.828283         8000
# 32     0.757576         8000
# 27     0.898990        10000
# 5      0.818182         8000
# 1      0.838384         4000
# 26     0.898990         3000
# 17     0.848485         4000
# 16     0.909091         2000
# 31     0.848485         4000
# 30     0.909091         2000
# 40     0.858586         4000
# 2      0.909091        10000
# 37     0.757576         2000
# 3      0.878788         2000
# 23     0.767677         1000
# 33     0.797980         1000
# 15     0.818182         1000
# 19     0.818182          500
# 4      0.777778          500
# 12     0.848485          500
# 36     0.747475          500
# 18     0.777778         6000
# 22     0.767677          500
# 8      0.797980         4000
# 34     0.888889        10000
# 20     0.838384         3000
# 6      0.868687         1000
# 9      0.777778          500
# 35     0.818182         1000
# 0      0.515152         3000
# 14     0.454545         2000
# 21     0.828283        10000
# 7      0.818182         3000
# 28     0.494949          500
# 25     0.747475          500
# 24     0.424242          500
# 11     0.747475          500
# 10     0.424242          500
# 38     0.424242          500
# 39     0.757576          500
#
#                                           best params  best accuracy train  \
# 41  {'activation': 'logistic', 'alpha': 0.01, 'ear...               0.9898
# 13  {'activation': 'tanh', 'alpha': 0.001, 'early_...               0.9898
# 29  {'C': 10, 'max_iter': 1000, 'penalty': 'l2', '...               0.9898
# 32  {'criterion': 'entropy', 'max_depth': 100, 'ma...               0.9898
# 27  {'activation': 'logistic', 'alpha': 0.001, 'ea...               0.9898
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...               0.9898
# 1   {'C': 10, 'max_iter': 1000, 'penalty': 'l2', '...               0.9898
# 26                   {'n_jobs': -1, 'voting': 'hard'}               0.9864
# 17  {'C': 1, 'degree': 1, 'gamma': 'scale', 'kerne...               0.9763
# 16                  {'alpha': 0.1, 'fit_prior': True}               0.9831
# 31  {'C': 1, 'degree': 1, 'gamma': 'scale', 'kerne...               0.9763
# 30                  {'alpha': 0.1, 'fit_prior': True}               0.9831
# 40                   {'n_jobs': -1, 'voting': 'hard'}               0.9898
# 2                   {'alpha': 0.1, 'fit_prior': True}               0.9831
# 37        {'learning_rate': 0.1, 'n_estimators': 200}               0.9797
# 3   {'C': 1, 'degree': 1, 'gamma': 'scale', 'kerne...               0.9729
# 23        {'learning_rate': 0.1, 'n_estimators': 200}               0.9864
# 33  {'criterion': 'entropy', 'max_depth': None, 'm...               0.9898
# 15  {'C': 10, 'max_iter': 1000, 'penalty': 'l2', '...               0.9864
# 19  {'criterion': 'entropy', 'max_depth': None, 'm...               0.9661
# 4   {'criterion': 'entropy', 'max_depth': 50, 'max...               0.9627
# 12                   {'n_jobs': -1, 'voting': 'hard'}               0.9661
# 36  {'learning_rate': 0.1, 'loss': 'deviance', 'ma...               0.9220
# 18  {'criterion': 'gini', 'max_depth': 50, 'max_fe...               0.9661
# 22  {'learning_rate': 0.1, 'loss': 'exponential', ...               0.8915
# 8   {'learning_rate': 0.1, 'loss': 'exponential', ...               0.9017
# 34  {'max_features': 0.7, 'max_samples': 0.7, 'n_e...               0.8881
# 20  {'max_features': 0.7, 'max_samples': 0.7, 'n_e...               0.8746
# 6   {'max_features': 0.7, 'max_samples': 0.7, 'n_e...               0.8949
# 9         {'learning_rate': 0.1, 'n_estimators': 100}               0.8712
# 35  {'max_features': 0.7, 'max_samples': 0.7, 'n_e...               0.6508
# 0   {'algorithm': 'auto', 'n_neighbors': 101, 'wei...               0.5932
# 14  {'algorithm': 'auto', 'n_neighbors': 101, 'wei...               0.5966
# 21  {'max_features': 0.7, 'max_samples': 0.7, 'n_e...               0.6169
# 7   {'max_features': 0.7, 'max_samples': 0.7, 'n_e...               0.6034
# 28  {'algorithm': 'auto', 'n_neighbors': 101, 'wei...               0.5627
# 25        {'learning_rate': 0.01, 'n_estimators': 50}               0.5254
# 24        {'learning_rate': 0.01, 'n_estimators': 50}               0.5254
# 11        {'learning_rate': 0.01, 'n_estimators': 50}               0.5254
# 10        {'learning_rate': 0.01, 'n_estimators': 50}               0.5254
# 38        {'learning_rate': 0.01, 'n_estimators': 50}               0.5254
# 39        {'learning_rate': 0.01, 'n_estimators': 50}               0.5254
#
#     best accuracy test
# 41              0.9899
# 13              0.9899
# 29              0.9899
# 32              0.9899
# 27              0.9899
# 5               0.9899
# 1               0.9899
# 26              0.9798
# 17              0.9798
# 16              0.9798
# 31              0.9798
# 30              0.9798
# 40              0.9798
# 2               0.9798
# 37              0.9798
# 3               0.9798
# 23              0.9596
# 33              0.9596
# 15              0.9596
# 19              0.9495
# 4               0.9293
# 12              0.9293
# 36              0.9091
# 18              0.8889
# 22              0.8788
# 8               0.8687
# 34              0.8384
# 20              0.8182
# 6               0.8081
# 9               0.8081
# 35              0.5758
# 0               0.5152
# 14              0.5152
# 21              0.4949
# 7               0.4848
# 28              0.4646
# 25              0.4242
# 24              0.4242
# 11              0.4242
# 10              0.4242
# 38              0.4242
# 39              0.4242

# %%
t2 = time.perf_counter()
print('Seconds taken to run:', round(t2-t1, 0))
print('Minutes taken to run:', round((t2-t1)/60, 0))
print('Hours taken to run:', round((t2-t1)/3600, 2))
# Out:
# Seconds taken to run: 2182.0
# Minutes taken to run: 36.0
# Hours taken to run: 0.61

# %% [markdown]
# ## **Conclusions**:
#
# Feature Selection:
# *   Most of the models did well with not more than 6000 features. many with 10000.
# *   Best model - MLP. also MNB.
# *   Worse model - AdaBoost.
# *   Max accuracy - 90%. worse from notebook #2
#
# Parameter Tuning:
#
# *   Best model is still MLP. LR, DT, RF.
# *   Max accuracy - 98.99%. Max F1 - 98.99%
# *   param tuning improved a lot.
#
#
# **Generally - Under Sampling has a big improvment potential on the data.
